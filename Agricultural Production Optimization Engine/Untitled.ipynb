# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\umair\Documents\Book1.xlsx')
# Out:
#      Unnamed: 0 SALES REPORT AS PER SALES TAX INVOICE   Unnamed: 2  \
# 0           Sno                                 Date   Qty Mtr/Kgs
# 1           NaN                   2021-06-30 00:00:00       139.73
# 2           NaN                   2021-06-30 00:00:00          360
# 3           NaN                   2021-06-30 00:00:00          345
# 4           NaN                   2021-06-30 00:00:00          360
# ...         ...                                   ...          ...
# 4791        NaN                   2020-07-01 00:00:00          200
# 4792        NaN                   2020-07-01 00:00:00         1055
# 4793        NaN                   2020-07-01 00:00:00          860
# 4794        NaN                                   NaN          NaN
# 4795        NaN                                   NaN          NaN
#
#            Unnamed: 3  Unnamed: 4 Unnamed: 5   Unnamed: 6    Unnamed: 7  \
# 0     Qty Kgs in FBR         Desc  Rate / kg    Ex- Value     S.Tax 17%
# ...
